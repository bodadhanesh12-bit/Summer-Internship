# %% [markdown]
# Notebook 01 — Data Loading

# %% [markdown]
# Step 1 — Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Step 2 — Upload / Load Dataset

# %% [markdown]
# Option A — Google Colab Upload

# %%
from google.colab import files

# Upload file from your computer
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d40234b3-97f8-4d71-b877-37fccdd596fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d40234b3-97f8-4d71-b877-37fccdd596fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Option B — Load from Path

# %%
df = pd.read_csv('/content/dataset.csv')

# %% [markdown]
# Step 3 — Dataset Preview

# %%
import pandas as pd

# Get the filename from the uploaded dictionary
file_name = list(uploaded.keys())[0]

# 1. Load your dataset
df = pd.read_csv(file_name)

# 2. Now your exploration code will work perfectly:
print("--- First 5 Rows ---")
print(df.head())

print("\n--- Last 5 Rows ---")
print(df.tail())

print("\n--- 5 Random Rows ---")
print(df.sample(5))
# Out:
# --- First 5 Rows ---
#    Unnamed: 0  CustomerID  Gender  SeniorCitizen  Tenure  MonthlyCharges  \
# 0           0           0    Male              0      55          111.88
# 1           1           1  Female              1      36           58.70
# 2           2           2    Male              0      37          118.86
# 3           3           3    Male              1      14           96.14
# 4           4           4    Male              1      27           28.05
#
#          Contract     PaymentMethod  Churn  TotalCharges
# 0        Two year      Mailed check      0       6153.40
# 1        Two year  Electronic check      0       2113.20
# 2        One year  Electronic check      0       4397.82
# 3  Month-to-month      Mailed check      1       1345.96
# 4        Two year      Mailed check      0        757.35
#
# --- Last 5 Rows ---
#       Unnamed: 0  CustomerID  Gender  SeniorCitizen  Tenure  MonthlyCharges  \
# ...

# %% [markdown]
# Step 4 — Dataset Shape

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 10000
# Columns: 10

# %% [markdown]
# Step 5 — Column Names

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'CustomerID',
#  'Gender',
#  'SeniorCitizen',
#  'Tenure',
#  'MonthlyCharges',
#  'Contract',
#  'PaymentMethod',
#  'Churn',
#  'TotalCharges']

# %% [markdown]
# Step 6 — Save Raw Backup

# %%
df.to_csv("raw_dataset_backup.csv", index=False)
